# %%
from the_quiver import *
from matplotlib import pyplot as graph

def f2(t, y, z):
    return -0.01*(20-y)

# f1 is of dy/dt form

def f1(t, y, z):
    return z

# Boundary values in the given question
t_1 = 0; t2 = 10
y1 = 40; y2 = 200

t, y, z = SM(f2, f1, t_1, y1, t2,y2, 5, 30, 0.05)

print("At 100 degree celcius, the distance x along the rod is " + str(t[89]) + " m")
graph.plot(t,y,'r')
graph.xlabel("Distance - x")
graph.ylabel("Temperature - T")
graph.title("Temperature vs Distance curve")
# Out:
# At 100 degree celcius, the distance x along the rod is 4.449999999999992 m
# Text(0.5, 1.0, 'Temperature vs Distance curve')
