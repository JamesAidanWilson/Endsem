# %%
from the_quiver import *
from matplotlib import pyplot as graph
import numpy as np

data = readtxt("esem_fit2.dat")

X = [data[i][0] for i in range(len(data))]
Y = [data[i][1] for i in range(len(data))]


quad_fit = np.poly1d(np.polyfit(X,Y,2))
polyline = np.linspace(20, 100, 50)
graph.plot(X,Y)
graph.plot(polyline, quad_fit(polyline))
graph.show()

print(quad_fit)

def f1(x):
    return -0.02816*x + 2.31

Bisection(80,100,0.00001,f1)

r = 82.03125

print(-0.02816*r + 2.31*r + 5.724, " is the highest point.")
# Out:
#           2
# -0.02816 x + 2.31 x + 5.724
# No. of iterations (i)        Successive Bisections (half bracket length)
#          0                     10.0
#
#          1                     5.0
#
#          2                     2.5
#
#          3                     1.25
#
#          4                     0.625
#
#          5                     0.3125
#
#          6                     0.15625
#
#          7                     0.15625
#
#          8                     0.15625
#
#          9                     0.15625
#
#          10                     0.15625
#
#          11                     0.15625
#
#          12                     0.15625
#
#          13                     0.15625
#
#          14                     0.15625
#
# 82.03125 is the root.
# 192.9061875  is the highest point.
